# %% [markdown]
# # Final Project Outline_Aman
# #### The manual gis procedures were replaced with Python ArcGIS workflow, which took a several plugins and frameworks to execute the system. Therefore, I didn't go through the .aprx or .tbx toolbox procedure. The jupyter notebook scripts should work properly for executing the automated workflow. The video presentation provides the live go through the scripts
#
# Automated Workflow: The project consists of two parts.
#
# Part A Scripts:
#
# - 01_FinalProjectPt1_Aman
# - 02_FinalProjectPt1_SVI_GoogleAPI
# - 03_FinalProjectPt1_PspNet
#
# Part B Scripts:
#
# - 04_FinalProjectPt2_Aman
#
# Folders:
#
# - FinalProjectPt1Data.zip (For Part A)
# - FinalProjectPt2Data.zip (For Part B)
#
# Results outcomes thoughout different phases (for back up view)
# - OutputFiles_AllResults

# %% [markdown]
# # Project Topic
#
# 'Prediction of Street Preferability using pedestrian-urban features relationship measures'.

# %% [markdown]
# # Problem Motivation
#
#
# #### The overall problem to address the Big picture. We'll cover (2) for this project for the workflow. Further statistical analysis and space syntax/Least cost path analyses need to be conducted in future.
#
# 1) Which path do people prefer to take? 2) Whether these choices are influenced by the urban attributes?
#
# #### The basic framework to address the problem (Red-marked will be covered in the final project):
#
# ![framework.png](attachment:framework.png)

# %% [markdown]
# ## Steps
#
# - The steps towards addressing the problem is provided below
# ![Framework.PNG](attachment:Framework.PNG)

# %% [markdown]
# # SAVE YOUR NOTEBOOK, then `File > Close and Halt`

# %% [markdown]
# ![MatisziwCopyright2019.bmp](attachment:MatisziwCopyright2019.bmp)
